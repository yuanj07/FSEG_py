# %%
from utils.fseg_filters import io_from_prompt
from FctSeg import run_fct_seg

img = io_from_prompt("Images/house.png", shape_size=(876, 706), dtype="uint8")

# %%
mask = run_fct_seg(img, ws=25, n_segments=3, omega=.045, nonneg_constraint=True, save_dir="ResultImages/", save_file_name="Test4.png")
# Out:
# ----------------------------------------------------------------------------------------------------
# making the convergence condition with parameters : max_iteration_convergence = 50, max_convergence_error = 1e-05
# ----------------------------------------------------------------------------------------------------
#
# iteration = 0 | diference norm = 0.2790689468383789 | max_error for convergence criteria = 1e-05
# iteration = 1 | diference norm = 0.004119258373975754 | max_error for convergence criteria = 1e-05
# iteration = 2 | diference norm = 0.0002256330189993605 | max_error for convergence criteria = 1e-05
# iteration = 3 | diference norm = 1.2499825061240699e-05 | max_error for convergence criteria = 1e-05
# iteration = 4 | diference norm = 4.418407115736045e-07 | max_error for convergence criteria = 1e-05
#
# ----------------------------------------------------------------------------------------------------
# ...

# %%
print(mask.min())
print(mask.max())
# Out:
# 0
# 2
