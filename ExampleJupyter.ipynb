# %%
from utils.fseg_filters import io_from_prompt
from FctSeg import run_fct_seg

img = io_from_prompt("Images/house.png", shape_size=(876, 706), dtype="uint8")

# %%
mask = run_fct_seg(img, ws=25, n_segments=3, omega=.045, nonneg_constraint=True, save_dir="ResultImages/", save_file_name="Test4.png")
# Out:
# ----------------------------------------------------------------------------------------------------
# making the convergence condition with parameters : max_iteration_convergence = 50, max_convergence_error = 1e-05
# ----------------------------------------------------------------------------------------------------
#
# iteration = 0 | diference norm = 0.12016341835260391 | max_error for convergence criteria = 1e-05
# iteration = 1 | diference norm = 0.0008928670431487262 | max_error for convergence criteria = 1e-05
# iteration = 2 | diference norm = 6.899403524585068e-05 | max_error for convergence criteria = 1e-05
# iteration = 3 | diference norm = 4.832168087887112e-06 | max_error for convergence criteria = 1e-05
#
# ----------------------------------------------------------------------------------------------------
# starting the LSE with : max_iteration = 50 and max_error = 0.001
# ----------------------------------------------------------------------------------------------------
# /home/gabriel_macedo/GitRepos/FSEG_Algoritm/FctSeg.py:216: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   tmp, _, _, _ = LA.lstsq(np.dot(w0.T, w0) + np.eye(segn) * epsilon, np.dot(w0.T, Y.T))
# /home/gabriel_macedo/GitRepos/FSEG_Algoritm/FctSeg.py:218: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   tmp, _, _, _ = LA.lstsq(np.dot(h, h.T) + np.eye(segn) * epsilon, np.dot(h, Y))
# iteration = 0 | diference norm : 0.9588650897693235 | actual norm : 0.04113491023067651
# iteration = 1 | diference norm : 0.003418313662434329 | actual norm : 0.03771659656824218
# iteration = 2 | diference norm : 0.0008209882708222621 | actual norm : 0.03689560829741992
# FSEG runs in 5.62 seconds.

# %%
print(mask.min())
print(mask.max())
# Out:
# 0
# 2
