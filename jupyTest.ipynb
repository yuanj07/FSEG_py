# %%
from utils.fseg_filters import io_from_prompt
from FctSeg import run_fct_seg

img = io_from_prompt("Images/house.png", shape_size=(876, 706), dtype="uint8")

# %%
mask = run_fct_seg(img, ws=25, n_segments=3, omega=.045, nonneg_constraint=True, save_dir="ResultImages/", save_file_name="Test4.png")
# Out:
# /home/gabriel_macedo/GitRepos/FSEG_Algoritm/FctSeg.py:181: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   tmp, _, _, _ = LA.lstsq(np.dot(w0.T, w0) + np.eye(segn) * .01, np.dot(w0.T, Y.T))
# /home/gabriel_macedo/GitRepos/FSEG_Algoritm/FctSeg.py:183: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   tmp, _, _, _ = LA.lstsq(np.dot(h, h.T) + np.eye(segn) * .01, np.dot(h, Y))
# 0 0.9588650897693235 0.04113491023067651
# 1 0.003418313662434329 0.03771659656824218
# FSEG runs in 7.25 seconds.

# %%
print(mask.min())
print(mask.max())
# Out:
# 0
# 2
